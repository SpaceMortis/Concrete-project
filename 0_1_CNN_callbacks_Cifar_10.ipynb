# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

(X_train_cifar, y_train_cifar), (X_test_cifar, y_test_cifar) = datasets.cifar10.load_data()
X_train_cifar, X_test_cifar = X_train_cifar / 255.0, X_test_cifar / 255.0

print(" CIFAR-10 Data has been successfully loaded and prepared.")
# Out:
#  CIFAR-10 Data has been successfully loaded and prepared.

# %%
model_cifar_improved = models.Sequential([

    layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)),
    layers.BatchNormalization(),
    layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),

    layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.3),

    layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')
])

model_cifar_improved.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model_cifar_improved.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ...

# %%
callbacks_list = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ModelCheckpoint('best_cifar_model.keras', monitor='val_accuracy', save_best_only=True)
]

history_cifar = model_cifar_improved.fit(
    X_train_cifar, y_train_cifar,
    epochs=30,
    batch_size=64,
    validation_data=(X_test_cifar, y_test_cifar),
    callbacks=callbacks_list
)
# Out:
# Epoch 1/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 346s 435ms/step - accuracy: 0.4331 - loss: 1.6585 - val_accuracy: 0.5571 - val_loss: 1.2425
# Epoch 2/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 387s 442ms/step - accuracy: 0.6124 - loss: 1.0911 - val_accuracy: 0.6782 - val_loss: 0.9091
# Epoch 3/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 379s 437ms/step - accuracy: 0.6754 - loss: 0.9246 - val_accuracy: 0.6837 - val_loss: 0.8944
# Epoch 4/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 384s 441ms/step - accuracy: 0.7093 - loss: 0.8316 - val_accuracy: 0.7345 - val_loss: 0.7637
# Epoch 5/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 384s 443ms/step - accuracy: 0.7337 - loss: 0.7723 - val_accuracy: 0.7600 - val_loss: 0.6934
# Epoch 6/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 387s 449ms/step - accuracy: 0.7466 - loss: 0.7238 - val_accuracy: 0.7734 - val_loss: 0.6481
# Epoch 7/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 343s 438ms/step - accuracy: 0.7652 - loss: 0.6787 - val_accuracy: 0.7719 - val_loss: 0.6527
# Epoch 8/30
# ...
